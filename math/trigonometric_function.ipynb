# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

# %% [markdown]
# ## 三角関数
#
# ![trigonometric](trigonometric.png)
#
# ### sin cos tan (三角比:直角三角形の辺の比)
#
# - sinθ = b/c
# - conθ = a/c
# - tanθ = b/a
#
# ![sin cos tan](sin_cos_tan_table.png)
#
# ラジアン [`rad`] θ = 円（扇形）の孤の長さ(L) ÷ 円の半径(r) .
#
# 180° = π [rad]  ラジアンは180°に相当する。90°はπ/2
#
# https://ja.wikipedia.org/wiki/%E4%B8%89%E8%A7%92%E9%96%A2%E6%95%B0
#
# Numpyの`sin()`関数と`cos()`関数
#
# 円周率は、`np.pi`

# %%
# 数式 y = sin x, y = cos x をPythonで実装
x = np.linspace(-np.pi, np.pi) # -π から π (ラジアン)まで
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.plot(x, y_sin, label='sin')
plt.plot(x, y_cos, label='cos')
plt.legend()

plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

# %% [markdown]
# `sin()`関数は、`cos()`関数をx方向にπ/2だけずらしたものになる

# %%
# y = tan x をPythonで実装
x = np.linspace(-1.3, 1.3) # # -1.3 から 1.3 (ラジアン)まで
y_tan = np.tan(x)

plt.plot(x, y_tan, label='tan')
plt.legend()

plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

# %% [markdown]
# - `tan()`関数は、-π/2より大きくπ/2より小さい範囲で変化
# - -π/2に近づくと無限に小さくなり、π/2に近づくと無限に大きくなる
