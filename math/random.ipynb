# %% [markdown]
# ## 乱数
# - 規則性のない、予測できない数値
# - AI学習時にパラメータに使用

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# 0~5までの乱数に、1を加える
r_int = np.random.randint(6) + 1

r_int
# Out:
# 2

# %%
# 0~1の間の少数をランダムに返す (均一な乱数)
r_dec = np.random.rand()

r_dec
# Out:
# 0.12158596436579572

# %%
# 均一な乱数
n = 1000
x = np.random.rand(n) # 0-1の均一な乱数
y = np.random.rand(n) # 0-1の均一な乱数

# 均一に分布されていることが確認できる
plt.scatter(x,y) # 散布図のプロット
plt.grid()
plt.show()

# %%
# 偏った関数 (正規分布に従う確率で乱数を返す)
n = 1000
x = np.random.randn(n)
y = np.random.randn(n)

# 均一に分布されていることが確認できる
plt.scatter(x,y) # 散布図のプロット
plt.grid()
plt.show()
